# %%
println("Hello World")
# Out:
# Hello World

# %%
println("testing this lab notebook <3")
# Out:
# testing this lab notebook <3

# %%
using Printf
using Statistics
using Plots

# %%
df = 120
df ="dog"
df = 'is'
# Out:
# syntax: character literal contains multiple characters
#
# Stacktrace:
#  [1] top-level scope at In[17]:3
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [3] execute_code(::String, ::String) at /Users/karlor/.julia/packages/IJulia/a1SNk/src/execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/karlor/.julia/packages/IJulia/a1SNk/src/execute_request.jl:86
#  [5] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [6] invokelatest at ./essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at /Users/karlor/.julia/packages/IJulia/a1SNk/src/eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
println(df)
# Out:
# dog

# %%
x = 1:10; y = rand(10, 2)
plot(x, y, title = "Two Lines", label = ["Line 1" "Line 2"], lw = 3)

# %%
plot(x,y)

# %%
p1 = plot(x, y) # Make a line plot
p2 = scatter(x, y) # Make a scatter plot
p3 = plot(x, y, xlabel = "This one is labelled", lw = 3, title = "Subtitle")
p4 = histogram(x, y) # Four histograms each with 10 points? Why not!
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %%
using Plots

@userplot CirclePlot
@recipe function f(cp::CirclePlot)
    x, y, i = cp.args
    n = length(x)
    inds = circshift(1:n, 1 - i)
    linewidth --> range(0, 10, length = n)
    seriesalpha --> range(0, 1, length = n)
    aspect_ratio --> 1
    label --> false
    x[inds], y[inds]
end

n = 150
t = range(0, 2π, length = n)
x = sin.(t)
y = cos.(t)

anim = @animate for i ∈ 1:n
    circleplot(x, y, i)
end
gif(anim, "anim_fps15.gif", fps = 15)
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/karlor/Box Sync/codes/anim_fps15.gif
# └ @ Plots /Users/karlor/.julia/packages/Plots/5ItHH/src/animation.jl:104
# Plots.AnimatedGif("/Users/karlor/Box Sync/codes/anim_fps15.gif")
